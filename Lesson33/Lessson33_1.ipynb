# %% [markdown]
# ### Домашне завдання 33

# %%
import matplotlib as ml
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
import seaborn as sb

# %% [markdown]
# ### Завдання 1
# Загрузка DataFrame з файлу csv.

# %%
df=pd.read_csv('cars1.csv')
df
# Out:
#                        Car   Cost  Fuel  Speed  Load_capacity      Type
# 0             Honda Accord  32990   9.1    210            416     Sport
# 1               Honda CR-V  27000   9.8    188            520     Sedan
# 2                   BMW X6  50000  10.1    240            600     Sport
# 3      Bentley Continental  75000  14.5    330            358     Sport
# 4        Volkswagen Amarok  30000   7.6    179            835  Families
# 5                Volvo S60  35000   4.1    190            415     Sedan
# 6            Infiniti JX35  30000  10.7    190            534     Sedan
# 7   Land Rover Range Rover  60000   7.5    210            840     Sport
# 8                 Lexus CT  55000   4.1    180            360  Families
# 9                  Mazda 3  24000   7.8    174            460  Families
# 10   Mercedes-Benz A-Class  50000   5.8    202            565     Sport
# 11         Mini Countryman  25000   7.9    223            510     Sport
# 12          Mitsubishi ASX  28000   7.6    186            580     Sedan
# 13    Mitsubishi Outlandar  35000   7.0    200            640     Sedan
# 14          Nissan Qashqai  28000   8.0    181            415  Families
# 15             Skoda Fabia  16000   4.7    164            515  Families
# 16               Toyota 86  27000   7.8    226            403     Sport
# 17             Ford Escape  20000  10.2    187            476  Families
# 18          Chevrolet Aveo  15000   7.1    186            445  Families
# 19         Hyundai Elantra  24000   7.1    202            543  Families

# %% [markdown]
# ### Завдання 2
# Візуалізація залежностей. Fuel-Cost, Fuel-Speed, Speed-Load_capacity.

# %%
fig=plt.figure(figsize=(15,5), dpi=80)
ax1=fig.add_subplot(1,3,1)
ax1.set_title('Fuel-Cost relation')
ax1.set_xlabel('Fuel')
ax1.set_ylabel('Cost')
ax1.plot(df['Fuel'],df['Cost'],color='Green')

ax2=fig.add_subplot(1,3,2)
ax2.set_title('Fuel-Speed relation')
ax2.set_xlabel('Fuel')
ax2.set_ylabel('Speed')
ax2.scatter(df['Fuel'],df['Speed'],color='Red')

ax3=fig.add_subplot(1,3,3)
ax3.set_title('Fuel-Load_capacity relation')
ax3.set_xlabel('Speed')
ax3.set_ylabel('Load_capacity')
ax3.scatter(df['Speed'],df['Load_capacity'],color='Blue')

# %% [markdown]
# ### Завдання 3
# Побудова гістограми для розділення автомобілів на 5 груп за швидкістю.

# %%
fig=plt.figure(figsize=(9,5), dpi=80)
ax=fig.add_subplot()
ax.set_title('Histogram 5 groups speed')
ax.set_xlabel('Groups')
ax.set_ylabel('Speed')
ax.hist(df['Speed'],5,width=25)
# Out:
# (array([11.,  7.,  1.,  0.,  1.]),
#  array([164. , 197.2, 230.4, 263.6, 296.8, 330. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ### Завдання 4
# Коробковий графік для відображення швидкостей всіх марок.

# %%
fig=plt.figure(figsize=(8,6), dpi=80)
ax=fig.add_subplot()
ax.set_title('Box plot speed cars')
ax.set_xlabel('Cars')
ax.set_ylabel('Speed')
ax.boxplot(df['Speed'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1edc23c6320>,
#   <matplotlib.lines.Line2D at 0x1edc23c65c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1edc23c6860>,
#   <matplotlib.lines.Line2D at 0x1edc23c6b00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1edc23c6080>],
#  'medians': [<matplotlib.lines.Line2D at 0x1edc23c6da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1edc23c7040>],
#  'means': []}

# %% [markdown]
# ##### Коробковий графік відображення скоростей авто за іх типами (Seaborn)

# %%
sb.boxplot(x="Type", y="Speed", data=df)
# Out:
# <AxesSubplot: xlabel='Type', ylabel='Speed'>

# %% [markdown]
# ### Завдання 5
# Парний графік для відображення залежностей величин датасету за допомогою библіотеки Seaborn.

# %%
sb.pairplot(df,hue="Speed") # Залежності від параметру Speed

# %%
sb.pairplot(df,hue="Fuel") # Залежності від параметру Fuel

# %%
sb.pairplot(df) # Графіки усих залежностей
