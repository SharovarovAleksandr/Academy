# %% [markdown]
# <a href="https://colab.research.google.com/github/SharovarovAleksandr/Academy/blob/main/Lesson67/Lesson67_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Створюємо випадкові точки
x = np.random.rand(100, 1)
y = 2 * x + np.random.rand(100, 1) * 0.1

# Будуємо графік
plt.scatter(x, y)
plt.show()

# %%
# Створюємо модель нейронної мережі
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1, input_shape=(1,)))
model.compile(optimizer='sgd', loss='mse')

# Проводими навчання
history = model.fit(x, y, epochs=1000)

# Отримуємо результати 
print(model.summary())

# Створюємо лінійну регресію
x_test = np.linspace(0, 1, 100)
y_pred = model.predict(x_test)

# Візуалізуємо результати
plt.scatter(x, y)
plt.plot(x_test, y_pred, color='red')
plt.show()
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1444
# Epoch 2/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1215
# Epoch 3/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1036
# Epoch 4/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0876
# Epoch 5/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0748
# Epoch 6/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0646
# Epoch 7/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0554
# Epoch 8/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0473
# Epoch 9/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0416
# Epoch 10/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0378
# Epoch 11/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0339
# Epoch 12/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0303
# ...
